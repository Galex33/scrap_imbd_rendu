# %%
from controller import *
# Out:
# DROP TABLE --> OK

# %% [markdown]
# # Les films les plus récents font-ils les meilleures recettes ?

# %%
recette_year()

# %% [markdown]
# # Les films les plus récents dominent-ils le top 250 ?

# %%
top_recent()

# %% [markdown]
# # Quels sont les 5 réalisateurs rapportant les plus grosses recettes ?

# %%
top_directors_boxoffice()

# %% [markdown]
# # Quels sont les 5 réalisateurs ayant eu le plus de films dans le top 250 ?

# %%
top_directors_movies()

# %% [markdown]
# # Quel est le genre ayant eu le plus de succès selon l' année choisie ?

# %%
annee_genre('2008')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'genre_final'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-f6acd9c3c9a7> in <module>
# ----> 1 annee_genre('2008')
#
# ...
